# %%
# !source ~/.zsh_profile

# %%
import advertools as adv
import scrapy
products = ['mca', 'kmc', 'marketing']
words = ['jobs', 'careers', 'vacancies', 'full time', 'part time']

kw_df = adv.kw_generate(products, words)
kw_df
# Out:
#          Campaign   Ad Group                             Keyword  \
# 0    SEM_Campaign        Mca                            mca jobs
# 1    SEM_Campaign        Mca                            mca jobs
# 2    SEM_Campaign        Mca                          +mca +jobs
# 3    SEM_Campaign        Mca                         mca careers
# 4    SEM_Campaign        Mca                         mca careers
# ..            ...        ...                                 ...
# 625  SEM_Campaign  Marketing       part time vacancies marketing
# 626  SEM_Campaign  Marketing   +part +time +vacancies +marketing
# 627  SEM_Campaign  Marketing       part time full time marketing
# 628  SEM_Campaign  Marketing       part time full time marketing
# 629  SEM_Campaign  Marketing  +part +time +full +time +marketing
#
#     Criterion Type               Labels
# 0            Exact                 Jobs
# 1           Phrase                 Jobs
# 2            Broad                 Jobs
# ...

# %%
def get_sitemaps(url='https://google.co.in/robots.txt'):
    try:
        df = adv.sitemap_to_df(url, recursive=False)
        return df
    except:
        return None

# %%
import advertools as adv
adv.crawl('https://example.com', 'my_output_file.jl', follow_links=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/preetisharma/Desktop/SEO PROJECT/crawl.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/preetisharma/Desktop/SEO%20PROJECT/crawl.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import advertools as adv
# ----> <a href='vscode-notebook-cell:/Users/preetisharma/Desktop/SEO%20PROJECT/crawl.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> adv.crawl('https://example.com', 'my_output_file.jl', follow_links=True)
#
# File ~/.local/lib/python3.9/site-packages/advertools/spider.py:971, in crawl(url_list, output_file, follow_links, allowed_domains, exclude_url_params, include_url_params, exclude_url_regex, include_url_regex, css_selectors, xpath_selectors, custom_settings)
#     969         subprocess.run(command)
#     970 else:
# --> 971     subprocess.run(command)
#
# ...

# %%
import scrapy
